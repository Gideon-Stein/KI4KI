# %%
import sys
sys.path.append('..')

import pickle
import numpy as np
import pandas as pd
from utils.display_tools import load_best_forecasts

# %%
# %load_ext autoreload
# %autoreload 2

# %%
lot = pickle.load(open("../saves_and_results/cache_lot.p", "rb"))
data = pickle.load(open("../saves_and_results/cache_endog.p", "rb"))
exogs = pickle.load(open("../saves_and_results/cache_exogs.p", "rb"))


chronos = pd.read_csv("results/journal/chronos/Moehne_desc1_chronos_zero_shot_chronos.csv", index_col=0)
tfm = pd.read_csv("results/journal/tfm/Moehne_desc1_tfm_zero_shot_chronos.csv", index_col=0)

d = data["Moehne"]["desc1"]
y_ = d.loc[d.index.year == 2020]

# %% [markdown]
# ### Table for the PS points

# %%
forec = {}
model_stack = {}
for x in [str(n) for n in range(0,4)]:
    model_spec, forecasts = load_best_forecasts("results/journal/" + x, direction="desc1")
    model_stack[x] = model_spec

    if (x == "1")  or (x == "2"):
        counter = [x for x in forecasts.keys() if "sarimax" not in x]
        counter = [x for x in counter if "var" not in x]
    else:
        counter = forecasts.keys()
    forec[x] = {x: np.abs(forecasts[x] - y_.values).mean() for x in counter}
    forec[x] = pd.concat(forec[x], axis=1).round(3)



chronos = pd.read_csv("results/journal/chronos/Moehne_desc1_chronos_zero_shot_chronos.csv", index_col=0)
tfm = pd.read_csv("results/journal/tfm/Moehne_desc1_tfm_zero_shot_chronos.csv", index_col=0)
# append foundational models
forec["3"]["chronos"] = np.abs(y_ - chronos.values[:-1]).mean().round(3)
forec["3"]["tfm"] = np.abs(y_ - tfm.values[:-1]).mean().round(3)

forec["0"]["chronos"] = np.abs(y_ - chronos.values[:-1]).mean().round(3)
forec["0"]["tfm"] = np.abs(y_ - tfm.values[:-1]).mean().round(3)

# %%
final_naming = ["Full search", "Baseline", "Full Exogenous","Univariate"]
final = []
for n,x in enumerate(forec.keys()):
    print(x)
    a = forec[x].min(axis=1).round(2)
    naming = [forec[x].T.sort_values(y).index[0] for y in a.index]
    naming = [x[:3] if x != "sarimax" else "ari" for x in naming ]
    a = "\makecell{" + a.astype(str) + " // (" + naming +  ")}"

    final.append(a)
final = pd.concat(final, axis=1)
final.columns = final_naming
# Out:
# 0
# 1
# 2
# 3

# %%
for x in final.columns:
    final[x] = final[x].str.replace("sar", "ari")

# %%
final = final[["Baseline","Full Exogenous", "Univariate", "Full search"]]
final.columns = ["Baseline", "\makecell{Baseline + \\ Exogenous.}", "Univariate", "\makecell{Full model \\ search space}"]

# %%
final.T
# Out:
#                                                          10905  \
# Baseline                              \makecell{1.52 // (lin)}
# \makecell{Baseline + \ Exogenous.}    \makecell{1.56 // (lin)}
# Univariate                            \makecell{1.34 // (ari)}
# \makecell{Full model \ search space}   \makecell{1.5 // (tfm)}
#
#                                                          10961  \
# Baseline                              \makecell{1.02 // (lin)}
# \makecell{Baseline + \ Exogenous.}    \makecell{0.98 // (lin)}
# Univariate                            \makecell{0.81 // (lin)}
# \makecell{Full model \ search space}  \makecell{0.87 // (chr)}
#
#                                                          10982  \
# Baseline                              \makecell{1.18 // (lin)}
# \makecell{Baseline + \ Exogenous.}    \makecell{1.12 // (lin)}
# Univariate                            \makecell{0.97 // (ada)}
# \makecell{Full model \ search space}  \makecell{1.08 // (lin)}
#
#                                                          11038  \
# Baseline                              \makecell{3.85 // (lin)}
# \makecell{Baseline + \ Exogenous.}    \makecell{3.64 // (lin)}
# Univariate                            \makecell{3.68 // (ada)}
# \makecell{Full model \ search space}  \makecell{3.59 // (lin)}
#
#                                                          11161  \
# Baseline                              \makecell{2.05 // (lin)}
# \makecell{Baseline + \ Exogenous.}    \makecell{2.09 // (lin)}
# Univariate                            \makecell{2.05 // (ari)}
# \makecell{Full model \ search space}  \makecell{2.04 // (for)}
#
#                                                          11176  \
# Baseline                              \makecell{1.21 // (lin)}
# \makecell{Baseline + \ Exogenous.}     \makecell{1.0 // (lin)}
# Univariate                            \makecell{1.01 // (lin)}
# \makecell{Full model \ search space}  \makecell{1.06 // (var)}
#
#                                                          11208  \
# Baseline                              \makecell{1.56 // (lin)}
# \makecell{Baseline + \ Exogenous.}    \makecell{1.42 // (lin)}
# Univariate                            \makecell{1.39 // (ari)}
# \makecell{Full model \ search space}  \makecell{1.42 // (lin)}
#
#                                                          11243
# Baseline                              \makecell{3.16 // (lin)}
# \makecell{Baseline + \ Exogenous.}    \makecell{3.26 // (lin)}
# Univariate                            \makecell{3.11 // (ada)}
# \makecell{Full model \ search space}  \makecell{3.21 // (ada)}

# %%
print(final.T.to_latex())
# Out:
# \begin{tabular}{lllllllll}
# \toprule
# {} &                     10905 &                     10961 &                     10982 &                     11038 &                     11161 &                     11176 &                     11208 &                     11243 \\
# \midrule
# Baseline                             &  \textbackslash makecell\{1.52 // (lin)\} &  \textbackslash makecell\{1.02 // (lin)\} &  \textbackslash makecell\{1.18 // (lin)\} &  \textbackslash makecell\{3.85 // (lin)\} &  \textbackslash makecell\{2.05 // (lin)\} &  \textbackslash makecell\{1.21 // (lin)\} &  \textbackslash makecell\{1.56 // (lin)\} &  \textbackslash makecell\{3.16 // (lin)\} \\
# \textbackslash makecell\{Baseline + \textbackslash  Exogenous.\}   &  \textbackslash makecell\{1.56 // (lin)\} &  \textbackslash makecell\{0.98 // (lin)\} &  \textbackslash makecell\{1.12 // (lin)\} &  \textbackslash makecell\{3.64 // (lin)\} &  \textbackslash makecell\{2.09 // (lin)\} &   \textbackslash makecell\{1.0 // (lin)\} &  \textbackslash makecell\{1.42 // (lin)\} &  \textbackslash makecell\{3.26 // (lin)\} \\
# Univariate                           &  \textbackslash makecell\{1.34 // (ari)\} &  \textbackslash makecell\{0.81 // (lin)\} &  \textbackslash makecell\{0.97 // (ada)\} &  \textbackslash makecell\{3.68 // (ada)\} &  \textbackslash makecell\{2.05 // (ari)\} &  \textbackslash makecell\{1.01 // (lin)\} &  \textbackslash makecell\{1.39 // (ari)\} &  \textbackslash makecell\{3.11 // (ada)\} \\
# \textbackslash makecell\{Full model \textbackslash  search space\} &   \textbackslash makecell\{1.5 // (tfm)\} &  \textbackslash makecell\{0.87 // (chr)\} &  \textbackslash makecell\{1.08 // (lin)\} &  \textbackslash makecell\{3.59 // (lin)\} &  \textbackslash makecell\{2.04 // (for)\} &  \textbackslash makecell\{1.06 // (var)\} &  \textbackslash makecell\{1.42 // (lin)\} &  \textbackslash makecell\{3.21 // (ada)\} \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_147903/2873457219.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(final.T.to_latex())
