# %%
# Define source path for journal results
SOURCE_PATH = "../../save_and_results/old/journal/"

# %%
import sys
sys.path.append('..')

import pickle
import numpy as np
from matplotlib.pyplot import cm
import pandas as pd
from numpy import linspace
import matplotlib.pyplot as plt

from utils.display_tools import load_best_forecasts,  display_predictions_2

# %%
# %load_ext autoreload
# %autoreload 2

# %%
lot = pickle.load(open("../../save_and_results/cache_lot.p", "rb"))
data = pickle.load(open("../../save_and_results/cache_endog.p", "rb"))
exogs = pickle.load(open("../../save_and_results/cache_exogs.p", "rb"))

res_path = "../../save_and_results/old/journal/"

# %% [markdown]
# ## Draw some point

# %%
d = data["Moehne"]["desc1"]
y_ = d.loc[d.index.year == 2020]
ps_id = "11176"
cm_subsection = linspace(0, 1, 7)
colors_add = iter([cm.Accent(x) for x in cm_subsection])

colors_add = list(colors_add)
colors = {
"ari":colors_add[3],
"for": colors_add[1],
"ada": colors_add[2],
"lin": colors_add[0],
"var": colors_add[4],
"chr": colors_add[5],
"tfm": colors_add[6]
}

# %%
ms = {}
fc = {}
mae = {}

for x in [str(n) for n in range(0, 4)]:
    model_spec, forecasts = load_best_forecasts(
        res_path + x, direction="desc1"
    )
    stack = []
    for model_type in forecasts.keys():
        stack.append(forecasts[model_type][ps_id])
    naming = forecasts.keys()
    forecasts = pd.concat(stack, axis=1)
    forecasts.columns = naming
    if (x == "1") or (x == "2"):
        forecasts.drop(columns="sarimax", inplace=True)
    if x == "2":
        forecasts.drop(columns="var", inplace=True)

    score = pd.DataFrame(
        [np.abs(forecasts[x] - y_[ps_id].values).mean() for x in forecasts.columns],
        index=forecasts.columns,
        columns=["MAE"],
    )
    fc[x] = forecasts
    fc[x].columns = [x  if x != "sar" else "ari" for x in fc[x].columns.str[:3]]
    mae[x] = score
    mae[x].index = [x  if x != "sar" else "ari" for x in mae[x].index.str[:3]]
    mae[x] = score.round(2)


chronos = pd.read_csv(
    res_path + "chronos/Moehne_desc1_chronos_zero_shot_chronos.csv", index_col=0)[ps_id]
tfm = pd.read_csv(
    res_path + "/tfm/Moehne_desc1_tfm_zero_shot_chronos.csv", index_col=0)[ps_id]
# append foundational models
fc["3"]["chr"] = chronos.values[:-1]
fc["3"]["tfm"] = tfm.values[:-1]
mae["3"] = mae["3"].T
mae["3"]["chr"] = np.abs(y_[ps_id] - chronos.values[:-1]).mean()
mae["3"]["tfm"] = np.abs(y_[ps_id] - tfm.values[:-1]).mean()
mae["3"] = mae["3"].T

# %%
fig, axs = plt.subplots(2, 4, figsize=(20, 10))


for pack in [( axs[0, 0],axs[0, 1],"1"),( axs[0, 2],axs[0, 3],"2"),( axs[1, 0],axs[1, 1],"3"),( axs[1, 2],axs[1, 3],"0")]:
    display_predictions_2(
        fig,
        pack[0],
        d,
        fc[pack[2]],
        y_[ps_id],
        mae[pack[2]],
        colors=colors,
        fontsize=12,
        rs_fontsize=15,
        error_coords=[1, 7, 12],
        #error_coords=[10, -13.25, -2],
        rs_position=[10, 1],  #20,2
        add_stats_to_residual_plot=True,
        spacing=0.75, # 1.5
        provided_axes=pack[1],
        key=ps_id,
        shortening=False,
        ax2_inside=False,
        x_lim=[200, 360],
        y_lim=[-6,15], # []
        alphas=[0.0, 1.0],
        loc_2=[0.362, 0.78, 0.12, 0.18],
        marker="o",
    )

for c in [(1,0), (0,0)]:
    axs[c].set_ylabel("Deformation in mm", fontsize=18)

for c in [(0,0), (1,2), (1,0), (1,2)]:
    axs[c].set_xlabel("Time", fontsize=18)

naming = ["Baseline", "Additional exogenous variables", "Univariate", "Full model search space"]
for n,c in enumerate([(0,0), (0,2), (1,0), (1,2)]):
    axs[c].set_title(naming[n], fontsize=18, x=1.10)
    axs[c].legend(loc=4, fontsize=10)
plt.savefig("mdpi_3.pdf")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 5
#       1 fig, axs = plt.subplots(2, 4, figsize=(20, 10))
#       4 for pack in [( axs[0, 0],axs[0, 1],"1"),( axs[0, 2],axs[0, 3],"2"),( axs[1, 0],axs[1, 1],"3"),( axs[1, 2],axs[1, 3],"0")]:
# ----> 5     display_predictions_2(
#       6         fig,
#       7         pack[0],
#       8         d,
#       9         fc[pack[2]],
#      10         y_[ps_id],
#      11         mae[pack[2]],
#      12         colors=colors,
#      13         fontsize=12,
#      14         rs_fontsize=15,
#      15         error_coords=[1, 7, 12],
#      16         #error_coords=[10, -13.25, -2],
#      17         rs_position=[10, 1],  #20,2
#      18         add_stats_to_residual_plot=True,
#      19         spacing=0.75, # 1.5
#      20         provided_axes=pack[1],
#      21         key=ps_id,
#      22         shortening=False,
#      23         ax2_inside=False,
#      24         x_lim=[200, 360],
#      25         y_lim=[-6,15], # []
#      26         alphas=[0.0, 1.0],
#      27         loc_2=[0.362, 0.78, 0.12, 0.18],
#      28         marker="o",
#      29     )
#      31 for c in [(1,0), (0,0)]:
#      32     axs[c].set_ylabel("Deformation in mm", fontsize=18)
#
# File ~/project_repos/KI4KI/forecasting_pipeline/mdpi_publication/../utils/display_tools.py:193, in display_predictions_2(fig, axs, d, forecasts, y_, rmse, colors, residual_plot, key, x_lim, y_lim, r_2_round, fontsize, spacing, add_errors, add_stats_to_residual_plot, error_coords, provided_axes, shortening, ax2_inside, only_best_error, alphas, loc_2, rs_position, rs_fontsize, marker)
#     163 def display_predictions_2(
#     164     fig,
#     165     axs,
#    (...)    189     marker="o",
#     190 ):
#     192     if key != "Radial":
# --> 193         tickPos = list(np.where(d.index.weekofyear == 1)[0])
#     194         tickPos.append(tickPos[-1] + 66)
#     195         tickLabels = np.arange(2016, 2022)
#
# AttributeError: 'DatetimeIndex' object has no attribute 'weekofyear'
